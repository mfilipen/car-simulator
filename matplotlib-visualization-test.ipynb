# %% [markdown]
# # matplotlib visualization test

# %%
import core.matplotlibVis as plt
import numpy as np
# %matplotlib notebook

# %%
theta =  np.pi/3
steerAngle = -np.pi/6

robot = plt.robotPlt()
robot.plotRobot(0.1,0.1, theta,steerAngle)
# Out:
# <img src="data:image/png;base64,..." width="900">
